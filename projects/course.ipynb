# %%
## Bootcamp Course

# %% [markdown]
# ### Topics : Professional Data Analyst Bootcamp
# - Module 1: Data Analytics Fundamentals & U.S. Job Market Orientation
#     - What is Data Analytics? Career roles, trends, and tools
#     - Data Analyst vs Data Scientist vs BI Analyst
#     - Overview of analytics domains: business, marketing, healthcare, finance
#     - Types of data: structured, semi-structured, unstructured
#     - Data lifecycle & workflow in real-world U.S. companies
#     - Capstone project introduction & orientation
# - Module 2: Data Handling and Analysis with Microsoft Excel
#     - Excel basics: formatting, formulas, shortcuts
#     - IF, nested IF, VLOOKUP, HLOOKUP, XLOOKUP
#     - Pivot Tables and Slicers for dynamic analysis
#     - Scenario & sensitivity analysis
#     - Excel charts & dashboard elements
#     - Excel Data ToolPak for descriptive statistics
#     - Basic data cleaning in Excel
# - Module 3: SQL for Data Analysts – From Basics to Business Queries
#     - Introduction to relational databases (PostgreSQL/MySQL)
#     - SELECT, WHERE, GROUP BY, HAVING, ORDER BY
#     - Filtering, Sorting, Wildcards
#     - JOINs (INNER, LEFT, RIGHT, FULL OUTER)
#     - Aggregations: COUNT, SUM, AVG, MAX, MIN
#     - Window Functions: RANK, DENSE_RANK, LEAD, LAG
#     - Creating Views & Subqueries
#     - Real business cases: customer churn, revenue by category
# - Module 4: Python Programming for Data Analysis – Foundations
#     - Python setup (Jupyter + VS Code)
#     - Python syntax: variables, operators, loops, conditionals
#     - Lists, dictionaries, tuples, sets
#     - Functions & Lambda expressions
#     - Working with files and directories
#     - Error handling and debugging
#     - Git & GitHub basics (for portfolio + version control)
# - Module 5: Python for Data Cleaning, Manipulation & EDA
#     - Introduction to Pandas and NumPy
#     - Reading/writing CSV, Excel, and JSON data
#     - Data cleaning: handling missing values, duplicates, nulls
#     - Filtering, slicing, sorting, merging datasets
#     - GroupBy operations and aggregations
#     - Exploratory Data Analysis (EDA) with real-world datasets
#     - Regex & text cleaning for unstructured data
# - Module 6: AI-Powered Data Analytics with Python
#     - What is AI-driven analytics?
#     - Integrating OpenAI API for data insights
#     - Using ChatGPT or similar LLMs for dynamic summaries
#     - Building Natural Language Query systems
#     - Automating summary generation from large datasets
#     - Sentiment Analysis with Hugging Face Transformers
#     - Using ML-based outlier detection for anomaly analytics
# - Module 7: Python Data Visualization – Matplotlib, Seaborn, and Plotly
#     - Chart types: bar, line, histogram, scatter, box plot
#     - Heatmaps, pair plots, and correlation matrices
#     - Styling and color coding for clarity
#     - Plotly for interactive dashboards
#     - Real use case: visualize marketing performance / sales data
# - Module 8: Business Statistics for Analysts
#     - Descriptive statistics: mean, median, mode, SD, variance
#     - Probability basics and distributions (normal, binomial)
#     - Correlation vs causation
#     - Inferential statistics: confidence intervals, p-values
#     - Hypothesis testing (t-test, z-test basics)
#     - Simple & multiple linear regression with scikit-learn
# - Module 9: Data Visualization & Storytelling with Tableau
#     - Tableau basics: UI, connecting to files and databases
#     - Building bar, line, pie, heat maps, scatter plots
#     - Filtering, parameters, calculated fields
#     - Dashboard design & best practices
#     - Storytelling with Tableau Stories
#     - Publishing dashboards (Tableau Public & resume linkage)
#     - Final Tableau project linked with capstone
# - Module 10: Capstone Project 1
#     - Design a database schema with relevant business tables
#     - Clean and prepare raw sales data using SQL
#     - Write SQL queries to analyze sales by region, category, and customer segment
#     - Identify monthly and quarterly sales trends using SQL
#     - Determine top-performing customers and products
#     - Detect underperforming regions and product categories
#     - Export query results for Tableau visualization
#     - Create visualizations using bar, line, pie, and map charts in Tableau
#     - Build an interactive Tableau dashboard with filters and parameters
#     - Present business insights with visual storytelling
# - Module 11: Capstone Project 2
#     - Load and preprocess customer feedback data using Python
#     - Clean and structure data using Pandas
#     - Perform sentiment analysis using AI API or pre-trained models
#     - Generate automated insights using OpenAI or similar APIs
#     - Create visualizations using Matplotlib, Seaborn, or Plotly
#     - Display sentiment distribution and keyword frequency
#     - Build interactive plots and dashboards within Python
#     - Summarize customer feedback into key action points using AI
#     - Compile a complete Jupyter Notebook with code, insights, and visuals
#     - Present findings and AI-driven recommendations to stakeholders
#
# ### End here
